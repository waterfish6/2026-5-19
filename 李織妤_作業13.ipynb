# %% [markdown]
# <a href="https://colab.research.google.com/github/waterfish6/2026-5-19/blob/main/%E6%9D%8E%E7%B9%94%E5%A6%A4_%E4%BD%9C%E6%A5%AD13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 多張車輛辨識車牌號碼程式
# 安裝套件
# !pip install ultralytics easyocr -q
import zipfile
import os
import cv2
import random
import matplotlib.pyplot as plt
from ultralytics import YOLO
import easyocr
# 解壓 ZIP
zip_path = "/content/images.zip"
extract_path = "/content/images/images/images/images"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
print("解壓完成")

# 載入模型
model = YOLO("yolov8n.pt")
reader = easyocr.Reader(['en'])
# 輸出檔案
output_file = "car_OK.txt"
# 用來存「顯示用結果」
results_list = []
# 批次辨識
with open(output_file, "w", encoding="utf-8") as f:
    for img_name in os.listdir(extract_path):
        if not img_name.lower().endswith(('.jpg', '.png', '.jpeg')):
            continue
        img_path = os.path.join(extract_path, img_name)
        img = cv2.imread(img_path)
        if img is None:
            continue
        # YOLO 偵測
        results = model(img_path)
        plate_text = "NOT_FOUND"
        for r in results:
            for box in r.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                x1, y1 = max(0, x1), max(0, y1)
                x2, y2 = min(img.shape[1], x2), min(img.shape[0], y2)
                crop = img[y1:y2, x1:x2]
                ocr_result = reader.readtext(crop)
                text = "".join([t[1] for t in ocr_result]).strip()
                if text != "":
                    plate_text = text
                    cv2.rectangle(img, (x1, y1), (x2, y2), (0,255,0), 2)
                    cv2.putText(img, text, (x1, y1-10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.8,
                                (0,255,0), 2)
                    break
        # 寫入 txt
        f.write(f"{img_name}\t{plate_text}\n")
        # 存起來給「隨機顯示用」
        results_list.append((img_name, img, plate_text))
        print(f"{img_name} → {plate_text}")

# 隨機顯示 5 張結果
sample_results = random.sample(results_list, min(5, len(results_list)))
for img_name, img, text in sample_results:
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(8,5))
    plt.imshow(img_rgb)
    plt.title(f"{img_name} - {text}")
    plt.axis("off")
# Out:
# 解壓完成
#
# image 1/1 /content/images/images/images/images/Cars74.png: 448x640 1 bus, 65.2ms
# Speed: 11.2ms preprocess, 65.2ms inference, 37.4ms postprocess per image at shape (1, 3, 448, 640)
# Cars74.png → CZi7 Kod
#
# image 1/1 /content/images/images/images/images/Cars272.png: 288x640 2 cars, 1 bus, 45.2ms
# Speed: 1.9ms preprocess, 45.2ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
# Cars272.png → RXGL GDU
#
# image 1/1 /content/images/images/images/images/Cars47.png: 480x640 2 cars, 1 chair, 42.9ms
# Speed: 1.6ms preprocess, 42.9ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# Cars47.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars129.png: 512x640 2 cars, 44.7ms
# Speed: 3.1ms preprocess, 44.7ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
# Cars129.png → OPEC Loi
#
# image 1/1 /content/images/images/images/images/Cars293.png: 448x640 1 car, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars293.png → GBIB TCE
#
# image 1/1 /content/images/images/images/images/Cars248.png: 480x640 1 car, 11.8ms
# Speed: 3.2ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Cars248.png → HH12 DE1433
#
# image 1/1 /content/images/images/images/images/Cars330.png: 480x640 6 cars, 1 bus, 2 trucks, 1 traffic light, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Cars330.png → [alem
#
# image 1/1 /content/images/images/images/images/Cars185.png: 448x640 1 bus, 1 truck, 2 traffic lights, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars185.png → Iez BO6Aa/MF-90-00
#
# image 1/1 /content/images/images/images/images/Cars240.png: 384x640 2 cars, 1 truck, 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Cars240.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars103.png: 320x640 3 persons, 8 cars, 2 motorcycles, 2 trucks, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# Cars103.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars225.png: 416x640 1 car, 1 truck, 44.3ms
# Speed: 2.6ms preprocess, 44.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# Cars225.png → JA62 UAR
#
# image 1/1 /content/images/images/images/images/Cars130.png: 448x640 1 car, 1 truck, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars130.png → MHR 26 BR 9044
#
# image 1/1 /content/images/images/images/images/Cars101.png: 480x640 1 car, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars101.png → HR 26 BC 5514
#
# image 1/1 /content/images/images/images/images/Cars297.png: 384x640 1 car, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars297.png → IMAU 555
#
# image 1/1 /content/images/images/images/images/Cars390.png: 480x640 2 cars, 1 chair, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars390.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars45.png: 416x640 4 persons, 3 cars, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# Cars45.png → MDHiNghoot
#
# image 1/1 /content/images/images/images/images/Cars321.png: 640x512 8 cars, 42.8ms
# Speed: 2.4ms preprocess, 42.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
# Cars321.png → LOlG
#
# image 1/1 /content/images/images/images/images/Cars111.png: 384x640 1 car, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Cars111.png → MH 20 EE 7598
#
# image 1/1 /content/images/images/images/images/Cars128.png: 384x640 (no detections), 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Cars128.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars279.png: 480x640 1 person, 2 trucks, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars279.png → 8@16MOpoxol
#
# image 1/1 /content/images/images/images/images/Cars10.png: 384x640 1 clock, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Cars10.png → TN 37 Cs2765
#
# image 1/1 /content/images/images/images/images/Cars143.png: 448x640 6 cars, 3 traffic lights, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars143.png → MAziolt}
#
# image 1/1 /content/images/images/images/images/Cars24.png: 480x640 1 car, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars24.png → HR 26 BC 5514
#
# image 1/1 /content/images/images/images/images/Cars206.png: 480x640 1 car, 1 truck, 6.0ms
# Speed: 1.8ms preprocess, 6.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars206.png → LHR 26 BU 0300
#
# image 1/1 /content/images/images/images/images/Cars361.png: 480x640 (no detections), 12.4ms
# Speed: 2.7ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Cars361.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars356.png: 448x640 1 person, 2 cars, 1 bus, 6.7ms
# Speed: 2.3ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars356.png → FIN SLOcK MEDYALanhandkcoVattoBSMART2sMart
#
# image 1/1 /content/images/images/images/images/Cars427.png: 480x640 2 cars, 1 truck, 12.4ms
# Speed: 3.1ms preprocess, 12.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars427.png → 01 Cc Ia Q001Tener
#
# image 1/1 /content/images/images/images/images/Cars288.png: 352x640 2 cars, 2 trucks, 66.9ms
# Speed: 1.4ms preprocess, 66.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
# Cars288.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars151.png: 416x640 8 cars, 2 trucks, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# Cars151.png → LD2cadeeD
#
# image 1/1 /content/images/images/images/images/Cars134.png: 448x640 1 car, 4 bottles, 8.8ms
# Speed: 2.8ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars134.png → M9mlc
#
# image 1/1 /content/images/images/images/images/Cars346.png: 416x640 4 cars, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# Cars346.png → KA 03 AB3380
#
# image 1/1 /content/images/images/images/images/Cars27.png: 384x640 1 car, 1 truck, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Cars27.png → DZIZ YXR
#
# image 1/1 /content/images/images/images/images/Cars349.png: 448x640 7 cars, 1 truck, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars349.png → [Y56 EXF
#
# image 1/1 /content/images/images/images/images/Cars118.png: 416x640 1 car, 1 truck, 9.2ms
# Speed: 3.2ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# Cars118.png → JA62 UAR
#
# image 1/1 /content/images/images/images/images/Cars142.png: 320x640 4 cars, 1 bus, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# Cars142.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars383.png: 448x640 2 persons, 12 cars, 4 buss, 1 truck, 2 traffic lights, 12.3ms
# Speed: 2.6ms preprocess, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars383.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars91.png: 416x640 1 car, 1 traffic light, 10.5ms
# Speed: 2.3ms preprocess, 10.5ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
# Cars91.png → [eocudl
#
# image 1/1 /content/images/images/images/images/Cars15.png: 448x640 1 car, 8.4ms
# Speed: 2.4ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars15.png → Miig
#
# image 1/1 /content/images/images/images/images/Cars212.png: 480x640 1 truck, 1 cell phone, 9.6ms
# Speed: 2.6ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Cars212.png → KL 65 H 4383
#
# image 1/1 /content/images/images/images/images/Cars365.png: 448x640 1 car, 13.9ms
# Speed: 3.4ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars365.png → TN 21 BZ 0768
#
# image 1/1 /content/images/images/images/images/Cars363.png: 448x640 1 bus, 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# Cars363.png → nouof () UuutWIN4ZJ
#
# image 1/1 /content/images/images/images/images/Cars121.png: 480x640 5 persons, 12 cars, 11.5ms
# Speed: 3.1ms preprocess, 11.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Cars121.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars152.png: 416x640 5 persons, 1 car, 1 truck, 13.1ms
# Speed: 2.5ms preprocess, 13.1ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
# Cars152.png → DL49 AK49
#
# image 1/1 /content/images/images/images/images/Cars235.png: 384x640 1 car, 1 truck, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Cars235.png → [6J03JLO126
#
# image 1/1 /content/images/images/images/images/Cars227.png: 448x640 18 persons, 1 car, 1 motorcycle, 1 traffic light, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars227.png → DWEthens
#
# image 1/1 /content/images/images/images/images/Cars314.png: 352x640 1 car, 1 train, 7.7ms
# Speed: 1.4ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Cars314.png → J6Piv728
#
# image 1/1 /content/images/images/images/images/Cars99.png: 640x480 1 car, 1 bus, 46.6ms
# Speed: 1.8ms preprocess, 46.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Cars99.png → VemdT0uKa-09Ma2662
#
# image 1/1 /content/images/images/images/images/Cars220.png: 448x640 6 cars, 3 trucks, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Cars220.png → P[55565
#
# image 1/1 /content/images/images/images/images/Cars331.png: 480x640 1 person, 1 car, 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Cars331.png → HRZ0.Ce 19
#
# image 1/1 /content/images/images/images/images/Cars68.png: 448x640 16 persons, 2 cars, 1 truck, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars68.png → 0ur216
#
# image 1/1 /content/images/images/images/images/Cars22.png: 480x640 2 cars, 2 buss, 1 truck, 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars22.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars139.png: 480x640 12 cars, 1 truck, 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Cars139.png → Scoun
#
# image 1/1 /content/images/images/images/images/Cars171.png: 448x640 16 persons, 2 cars, 1 truck, 12.6ms
# Speed: 2.0ms preprocess, 12.6ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars171.png → 0ur216
#
# image 1/1 /content/images/images/images/images/Cars386.png: 480x640 4 cars, 8.4ms
# Speed: 2.3ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars386.png → AB 44887
#
# image 1/1 /content/images/images/images/images/Cars201.png: 384x640 2 cars, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars201.png → LR33 TEBOive
#
# image 1/1 /content/images/images/images/images/Cars38.png: 640x640 2 cars, 4 traffic lights, 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Cars38.png → OHG BCKKLook at her butt
#
# image 1/1 /content/images/images/images/images/Cars236.png: 288x640 1 person, 9 cars, 1 truck, 8.1ms
# Speed: 1.2ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
# Cars236.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars140.png: 448x640 1 person, 2 cars, 1 truck, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars140.png → ChoL _Anooo]
#
# image 1/1 /content/images/images/images/images/Cars274.png: 480x640 4 persons, 9 cars, 1 truck, 1 handbag, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars274.png → CENsD
#
# image 1/1 /content/images/images/images/images/Cars326.png: 480x640 1 person, 1 car, 1 bus, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars326.png → DL8CX 4850
#
# image 1/1 /content/images/images/images/images/Cars207.png: 640x544 (no detections), 46.4ms
# Speed: 2.0ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
# Cars207.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars52.png: 480x640 1 car, 2 trucks, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars52.png → HH15BD8877
#
# image 1/1 /content/images/images/images/images/Cars335.png: 640x640 2 cars, 1 traffic light, 6.7ms
# Speed: 2.9ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Cars335.png → notacop]e
#
# image 1/1 /content/images/images/images/images/Cars262.png: 512x640 1 car, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
# Cars262.png → ICYA KSY
#
# image 1/1 /content/images/images/images/images/Cars150.png: 480x640 1 person, 1 car, 1 bus, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Cars150.png → DL8CX 4850
#
# image 1/1 /content/images/images/images/images/Cars280.png: 448x640 8 cars, 10 traffic lights, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars280.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars362.png: 480x640 3 persons, 3 cars, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars362.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars89.png: 448x640 5 cars, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars89.png → TATSesn
#
# image 1/1 /content/images/images/images/images/Cars313.png: 512x640 1 car, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
# Cars313.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars204.png: 480x640 (no detections), 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars204.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars76.png: 480x640 (no detections), 5.8ms
# Speed: 1.7ms preprocess, 5.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars76.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars301.png: 320x640 1 car, 1 truck, 6.0ms
# Speed: 1.2ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# Cars301.png → 6526 JHD
#
# image 1/1 /content/images/images/images/images/Cars181.png: 640x384 1 car, 49.5ms
# Speed: 1.4ms preprocess, 49.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Cars181.png → Jhiihad
#
# image 1/1 /content/images/images/images/images/Cars348.png: 384x640 (no detections), 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars348.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars145.png: 448x640 1 person, 2 cars, 1 truck, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars145.png → ChoL _Anooo]
#
# image 1/1 /content/images/images/images/images/Cars170.png: 480x640 4 cars, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars170.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars116.png: 544x640 1 car, 45.2ms
# Speed: 1.8ms preprocess, 45.2ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
# Cars116.png → WtnlMK-35-32
#
# image 1/1 /content/images/images/images/images/Cars147.png: 352x640 1 car, 7.0ms
# Speed: 1.4ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Cars147.png → KLCACA2555
#
# image 1/1 /content/images/images/images/images/Cars247.png: 384x640 1 clock, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Cars247.png → TN 37 Cs2765
#
# image 1/1 /content/images/images/images/images/Cars54.png: 480x640 1 car, 1 truck, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars54.png → 3200Lik378
#
# image 1/1 /content/images/images/images/images/Cars176.png: 416x640 1 car, 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# Cars176.png → OndrcaandicemmgOCT"Balifomia__EEVQ? ETHROADLIeace
#
# image 1/1 /content/images/images/images/images/Cars138.png: 512x640 1 cell phone, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# Cars138.png → TN 02 BLWww suncardecors com
#
# image 1/1 /content/images/images/images/images/Cars258.png: 448x640 2 cars, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars258.png → ACS5Kau
#
# image 1/1 /content/images/images/images/images/Cars18.png: 512x640 1 car, 1 truck, 7.6ms
# Speed: 2.6ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
# Cars18.png → M666 YOB
#
# image 1/1 /content/images/images/images/images/Cars69.png: 448x640 1 truck, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars69.png → KWID
#
# image 1/1 /content/images/images/images/images/Cars83.png: 480x640 2 cars, 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars83.png → Coi UuiGo gleself-driving car
#
# image 1/1 /content/images/images/images/images/Cars133.png: 448x640 1 car, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars133.png → 12683oDIrDED
#
# image 1/1 /content/images/images/images/images/Cars426.png: 480x640 2 cars, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars426.png → CRAIG
#
# image 1/1 /content/images/images/images/images/Cars60.png: 480x640 (no detections), 5.8ms
# Speed: 1.6ms preprocess, 5.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Cars60.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars268.png: 480x640 1 car, 1 truck, 5.9ms
# Speed: 1.5ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars268.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars336.png: 480x640 1 person, 1 car, 1 bus, 6.0ms
# Speed: 1.9ms preprocess, 6.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars336.png → DL8CX 4850
#
# image 1/1 /content/images/images/images/images/Cars286.png: 480x640 1 person, 2 cars, 1 bus, 5.8ms
# Speed: 1.6ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars286.png → MIDLYPH
#
# image 1/1 /content/images/images/images/images/Cars298.png: 448x640 1 person, 5 cars, 1 bus, 1 truck, 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars298.png → ~AMBO
#
# image 1/1 /content/images/images/images/images/Cars263.png: 480x640 4 persons, 1 car, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars263.png → MH02 CB 454
#
# image 1/1 /content/images/images/images/images/Cars402.png: 384x640 2 cars, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars402.png → sgo5i
#
# image 1/1 /content/images/images/images/images/Cars153.png: 384x640 1 car, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Cars153.png → MH2080 20Eenetette uttnrTeHl
#
# image 1/1 /content/images/images/images/images/Cars39.png: 480x640 1 car, 2 trucks, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars39.png → HH15BD8877
#
# image 1/1 /content/images/images/images/images/Cars36.png: 480x640 1 person, 2 cars, 1 bus, 5.9ms
# Speed: 1.7ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars36.png → MIDLYPH
#
# image 1/1 /content/images/images/images/images/Cars90.png: 480x640 4 persons, 7 cars, 5.8ms
# Speed: 1.8ms preprocess, 5.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars90.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars241.png: 448x640 (no detections), 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars241.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars14.png: 384x640 (no detections), 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars14.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars226.png: 448x640 1 car, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars226.png → [19s4523
#
# image 1/1 /content/images/images/images/images/Cars191.png: 416x640 4 cars, 6.1ms
# Speed: 1.4ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# Cars191.png → KA 03 AB3380
#
# image 1/1 /content/images/images/images/images/Cars59.png: 480x640 1 car, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars59.png → Na
#
# image 1/1 /content/images/images/images/images/Cars95.png: 448x640 6 persons, 1 car, 11.3ms
# Speed: 2.5ms preprocess, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars95.png → MA'DoOgO?
#
# image 1/1 /content/images/images/images/images/Cars264.png: 640x640 1 car, 7.5ms
# Speed: 2.2ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Cars264.png → 2010]CDFM
#
# image 1/1 /content/images/images/images/images/Cars325.png: 384x640 6 cars, 1 truck, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Cars325.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars144.png: 544x640 3 cars, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
# Cars144.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars251.png: 384x640 2 cars, 1 truck, 7.6ms
# Speed: 1.4ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Cars251.png → hEL
#
# image 1/1 /content/images/images/images/images/Cars125.png: 416x640 3 persons, 6 cars, 1 suitcase, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# Cars125.png → RPeunruct66887
#
# image 1/1 /content/images/images/images/images/Cars169.png: 320x640 1 car, 1 bus, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# Cars169.png → PriV ATE
#
# image 1/1 /content/images/images/images/images/Cars43.png: 384x640 1 car, 7.2ms
# Speed: 1.4ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars43.png → MH2080 20Eenetette uttnrTeHl
#
# image 1/1 /content/images/images/images/images/Cars407.png: 448x640 1 truck, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars407.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars377.png: 384x640 2 cars, 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Cars377.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars105.png: 384x640 5 persons, 2 cars, 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars105.png → 5B412344Jp06546
#
# image 1/1 /content/images/images/images/images/Cars303.png: 480x640 1 car, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Cars303.png → JesuecaejurrebilorTRutHKL54 42670
#
# image 1/1 /content/images/images/images/images/Cars94.png: 512x640 1 car, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
# Cars94.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars332.png: 384x640 1 car, 1 truck, 6.1ms
# Speed: 1.4ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars332.png → DZIZ YXR
#
# image 1/1 /content/images/images/images/images/Cars216.png: 512x640 2 cars, 6.4ms
# Speed: 2.2ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# Cars216.png → OPEC Loi
#
# image 1/1 /content/images/images/images/images/Cars243.png: 480x640 (no detections), 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Cars243.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars310.png: 576x640 6 cars, 43.2ms
# Speed: 2.1ms preprocess, 43.2ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
# Cars310.png → LGET OIL
#
# image 1/1 /content/images/images/images/images/Cars381.png: 384x640 3 persons, 3 cars, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars381.png → 12080563
#
# image 1/1 /content/images/images/images/images/Cars252.png: 512x640 2 cars, 1 truck, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# Cars252.png → DAN 54P
#
# image 1/1 /content/images/images/images/images/Cars7.png: 448x640 1 car, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars7.png → YEe
#
# image 1/1 /content/images/images/images/images/Cars221.png: 384x640 2 persons, 1 car, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Cars221.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars115.png: 512x640 1 car, 1 truck, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# Cars115.png → M666 YOB
#
# image 1/1 /content/images/images/images/images/Cars291.png: 384x640 2 persons, 1 car, 1 truck, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars291.png → 74 024-6570
#
# image 1/1 /content/images/images/images/images/Cars192.png: 480x640 1 car, 1 truck, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars192.png → E4 GLE
#
# image 1/1 /content/images/images/images/images/Cars211.png: 480x640 1 stop sign, 5.8ms
# Speed: 1.6ms preprocess, 5.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars211.png → F 65022DUBA/L4?
#
# image 1/1 /content/images/images/images/images/Cars186.png: 384x640 1 car, 12.2ms
# Speed: 1.4ms preprocess, 12.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars186.png → 26 SPF-4
#
# image 1/1 /content/images/images/images/images/Cars406.png: 448x640 1 car, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# Cars406.png → 12683oDIrDED
#
# image 1/1 /content/images/images/images/images/Cars26.png: 384x640 1 car, 1 truck, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Cars26.png → L7IQA41232
#
# image 1/1 /content/images/images/images/images/Cars338.png: 448x640 6 cars, 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars338.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars188.png: 640x480 8 persons, 7 cars, 2 trucks, 4 traffic lights, 1 suitcase, 7.8ms
# Speed: 1.7ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Cars188.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars3.png: 384x640 1 car, 1 truck, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars3.png → DZIZ YXR
#
# image 1/1 /content/images/images/images/images/Cars49.png: 416x640 1 car, 1 traffic light, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# Cars49.png → [eocudl
#
# image 1/1 /content/images/images/images/images/Cars352.png: 640x480 8 cars, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# Cars352.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars70.png: 384x640 4 cars, 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars70.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars347.png: 352x640 4 cars, 1 truck, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
# Cars347.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars295.png: 416x640 1 car, 1 truck, 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# Cars295.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars197.png: 384x640 2 cars, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Cars197.png → LR33 TEBOive
#
# image 1/1 /content/images/images/images/images/Cars215.png: 384x640 1 car, 1 truck, 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Cars215.png → 7886 H)5
#
# image 1/1 /content/images/images/images/images/Cars351.png: 384x640 1 car, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars351.png → TgxaSCB7:RGd5]Thpper Cxt
#
# image 1/1 /content/images/images/images/images/Cars244.png: 480x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars244.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars289.png: 512x640 3 cars, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
# Cars289.png → 532h
#
# image 1/1 /content/images/images/images/images/Cars175.png: 480x640 2 cars, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars175.png → 1nDL4268
#
# image 1/1 /content/images/images/images/images/Cars189.png: 448x640 1 person, 2 cars, 1 truck, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars189.png → ChoL _Anooo]
#
# image 1/1 /content/images/images/images/images/Cars382.png: 480x640 2 cars, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Cars382.png → CRAIG
#
# image 1/1 /content/images/images/images/images/Cars223.png: 448x640 2 persons, 3 cars, 1 truck, 1 tie, 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Cars223.png → 8o01(Mike
#
# image 1/1 /content/images/images/images/images/Cars392.png: 448x640 (no detections), 7.5ms
# Speed: 1.7ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# Cars392.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars61.png: 480x640 1 person, 2 trucks, 8.1ms
# Speed: 1.6ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Cars61.png → 8@16MOpoxol
#
# image 1/1 /content/images/images/images/images/Cars316.png: 480x640 3 persons, 1 train, 1 truck, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Cars316.png → 4Hoz BB
#
# image 1/1 /content/images/images/images/images/Cars53.png: 480x640 1 car, 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Cars53.png → chio OSE
#
# image 1/1 /content/images/images/images/images/Cars300.png: 384x640 1 car, 1 truck, 7.8ms
# Speed: 1.4ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Cars300.png → L7IQA41232
#
# image 1/1 /content/images/images/images/images/Cars195.png: 384x640 1 car, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Cars195.png → Qu
#
# image 1/1 /content/images/images/images/images/Cars430.png: 384x640 2 cars, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars430.png → BCG 986
#
# image 1/1 /content/images/images/images/images/Cars167.png: 512x640 1 car, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# Cars167.png → 15-LK-10898
#
# image 1/1 /content/images/images/images/images/Cars64.png: 448x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars64.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars283.png: 352x640 3 persons, 14 cars, 2 buss, 1 truck, 6.1ms
# Speed: 1.2ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Cars283.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars187.png: 384x640 (no detections), 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Cars187.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars50.png: 384x640 (no detections), 9.4ms
# Speed: 2.6ms preprocess, 9.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Cars50.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars80.png: 480x640 1 truck, 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars80.png → BAD 231
#
# image 1/1 /content/images/images/images/images/Cars380.png: 384x640 1 car, 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Cars380.png → Dud
#
# image 1/1 /content/images/images/images/images/Cars317.png: 480x640 1 car, 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars317.png → HR 26 BC 5514
#
# image 1/1 /content/images/images/images/images/Cars203.png: 448x640 1 bus, 12.6ms
# Speed: 2.3ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars203.png → CZi7 Kod
#
# image 1/1 /content/images/images/images/images/Cars141.png: 448x640 1 car, 8.8ms
# Speed: 2.9ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# Cars141.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars379.png: 576x640 (no detections), 9.4ms
# Speed: 3.7ms preprocess, 9.4ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
# Cars379.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars108.png: 512x640 1 car, 1 truck, 14.5ms
# Speed: 3.2ms preprocess, 14.5ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
# Cars108.png → ReieMho1av8866
#
# image 1/1 /content/images/images/images/images/Cars399.png: 384x640 (no detections), 11.0ms
# Speed: 2.1ms preprocess, 11.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Cars399.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars424.png: 480x640 1 train, 10.6ms
# Speed: 2.9ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Cars424.png → KA 03 MG2784
#
# image 1/1 /content/images/images/images/images/Cars57.png: 384x640 2 cars, 11.5ms
# Speed: 2.3ms preprocess, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Cars57.png → JBKML : 324
#
# image 1/1 /content/images/images/images/images/Cars250.png: 416x640 2 cars, 1 truck, 15.9ms
# Speed: 2.6ms preprocess, 15.9ms inference, 3.6ms postprocess per image at shape (1, 3, 416, 640)
# Cars250.png → CoirrmPGoMN112
#
# image 1/1 /content/images/images/images/images/Cars213.png: 480x640 1 person, 1 car, 1 truck, 10.5ms
# Speed: 2.8ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Cars213.png → Irit TorotnDID
#
# image 1/1 /content/images/images/images/images/Cars102.png: 512x640 1 oven, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Cars102.png → 683611.36nrTD
#
# image 1/1 /content/images/images/images/images/Cars217.png: 384x640 2 cars, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Cars217.png → EEcISHRuzukI WESIERN MOIC; `AFR 2011|'MioAcan
#
# image 1/1 /content/images/images/images/images/Cars193.png: 448x640 1 car, 8.4ms
# Speed: 2.4ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars193.png → ToB83uS9
#
# image 1/1 /content/images/images/images/images/Cars358.png: 320x640 2 cars, 12.4ms
# Speed: 3.2ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# Cars358.png → P262 FDX
#
# image 1/1 /content/images/images/images/images/Cars367.png: 448x640 1 car, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Cars367.png → Who owns this car?GOOGLE
#
# image 1/1 /content/images/images/images/images/Cars322.png: 576x640 1 car, 1 airplane, 10.7ms
# Speed: 4.3ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 640)
# Cars322.png → 700V
#
# image 1/1 /content/images/images/images/images/Cars46.png: 576x640 (no detections), 8.8ms
# Speed: 4.0ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
# Cars46.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars104.png: 480x640 6 cars, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Cars104.png → EiboLZB
#
# image 1/1 /content/images/images/images/images/Cars412.png: 384x640 2 cars, 13.4ms
# Speed: 3.1ms preprocess, 13.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars412.png → LR33 TEBOive
#
# image 1/1 /content/images/images/images/images/Cars122.png: 480x640 4 persons, 9 cars, 1 truck, 1 handbag, 9.9ms
# Speed: 2.5ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars122.png → CENsD
#
# image 1/1 /content/images/images/images/images/Cars73.png: 384x640 1 car, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Cars73.png → TN 99F2378
#
# image 1/1 /content/images/images/images/images/Cars302.png: 320x640 (no detections), 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# Cars302.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars376.png: 448x640 1 car, 1 truck, 12.6ms
# Speed: 2.4ms preprocess, 12.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Cars376.png → B2228 HM
#
# image 1/1 /content/images/images/images/images/Cars136.png: 448x640 1 car, 1 truck, 5.7ms
# Speed: 1.6ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars136.png → Wak4a
#
# image 1/1 /content/images/images/images/images/Cars113.png: 480x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars113.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars11.png: 512x640 1 bus, 1 truck, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
# Cars11.png → LOR S16K
#
# image 1/1 /content/images/images/images/images/Cars146.png: 480x640 12 persons, 32 cars, 6 buss, 1 truck, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Cars146.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars67.png: 320x640 1 car, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# Cars67.png → MAaa BN 7077THEAL
#
# image 1/1 /content/images/images/images/images/Cars369.png: 512x640 1 car, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# Cars369.png → 15-LK-10898
#
# image 1/1 /content/images/images/images/images/Cars282.png: 512x640 1 oven, 7.5ms
# Speed: 1.7ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
# Cars282.png → 683611.36nrTD
#
# image 1/1 /content/images/images/images/images/Cars29.png: 480x640 2 cars, 1 motorcycle, 1 bus, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Cars29.png → 227 4POLICEHanaalPUHl9214THDT
#
# image 1/1 /content/images/images/images/images/Cars421.png: 480x640 3 cars, 1 truck, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars421.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars414.png: 448x640 1 car, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars414.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars100.png: 448x640 3 cars, 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Cars100.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars345.png: 480x640 1 bicycle, 2 cars, 1 truck, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Cars345.png → OHG MOdv
#
# image 1/1 /content/images/images/images/images/Cars398.png: 480x640 1 person, 2 trucks, 7.6ms
# Speed: 1.6ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars398.png → 8@16MOpoxol
#
# image 1/1 /content/images/images/images/images/Cars395.png: 512x640 1 car, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
# Cars395.png → ICYA KSY
#
# image 1/1 /content/images/images/images/images/Cars58.png: 416x640 1 cell phone, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# Cars58.png → MH01 @b 0001
#
# image 1/1 /content/images/images/images/images/Cars154.png: 640x480 1 car, 1 bus, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Cars154.png → VemdT0uKa-09Ma2662
#
# image 1/1 /content/images/images/images/images/Cars308.png: 480x640 1 car, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars308.png → HR 26 BC 5514
#
# image 1/1 /content/images/images/images/images/Cars249.png: 416x640 2 persons, 3 cars, 1 truck, 2 ties, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
# Cars249.png → KA 421.0852
#
# image 1/1 /content/images/images/images/images/Cars158.png: 480x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars158.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars92.png: 448x640 6 persons, 1 car, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars92.png → MA'DoOgO?
#
# image 1/1 /content/images/images/images/images/Cars96.png: 416x640 2 cars, 1 truck, 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# Cars96.png → CoirrmPGoMN112
#
# image 1/1 /content/images/images/images/images/Cars4.png: 384x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars4.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars13.png: 448x640 16 persons, 2 cars, 1 truck, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars13.png → 0ur216
#
# image 1/1 /content/images/images/images/images/Cars404.png: 640x608 3 cars, 1 truck, 45.2ms
# Speed: 3.4ms preprocess, 45.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 608)
# Cars404.png → BMH
#
# image 1/1 /content/images/images/images/images/Cars37.png: 448x640 1 car, 1 truck, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars37.png → FASTWRGN
#
# image 1/1 /content/images/images/images/images/Cars0.png: 352x640 1 car, 6.6ms
# Speed: 1.2ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Cars0.png → KLCACA2555
#
# image 1/1 /content/images/images/images/images/Cars387.png: 448x640 3 cars, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars387.png → HR26 4Z 5927
#
# image 1/1 /content/images/images/images/images/Cars327.png: 416x640 2 cars, 1 truck, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# Cars327.png → CoirrmPGoMN112
#
# image 1/1 /content/images/images/images/images/Cars324.png: 384x640 1 bus, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars324.png → VZLAF
#
# image 1/1 /content/images/images/images/images/Cars88.png: 480x640 1 person, 4 cars, 2 trucks, 1 traffic light, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars88.png → JerIollLelelDtt
#
# image 1/1 /content/images/images/images/images/Cars79.png: 576x640 6 cars, 6.6ms
# Speed: 2.9ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
# Cars79.png → LGET OIL
#
# image 1/1 /content/images/images/images/images/Cars397.png: 480x640 2 cars, 1 motorcycle, 1 bus, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars397.png → 227 4POLICEHanaalPUHl9214THDT
#
# image 1/1 /content/images/images/images/images/Cars51.png: 448x640 4 cars, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars51.png → YES Boss
#
# image 1/1 /content/images/images/images/images/Cars353.png: 416x640 4 cars, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# Cars353.png → KA 03 AB3380
#
# image 1/1 /content/images/images/images/images/Cars234.png: 384x640 1 car, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars234.png → IMAU 555
#
# image 1/1 /content/images/images/images/images/Cars209.png: 480x640 1 car, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Cars209.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars184.png: 384x640 3 cars, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Cars184.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars224.png: 480x640 2 cars, 1 truck, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars224.png → Li=
#
# image 1/1 /content/images/images/images/images/Cars378.png: 512x640 1 oven, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# Cars378.png → S7
#
# image 1/1 /content/images/images/images/images/Cars149.png: 480x640 2 cars, 1 motorcycle, 1 traffic light, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars149.png → 7VIGZ6J
#
# ...
# Cars372.png → HRZGCE 1485
#
# image 1/1 /content/images/images/images/images/Cars417.png: 480x640 1 truck, 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars417.png → BAD 231
#
# image 1/1 /content/images/images/images/images/Cars196.png: 416x640 3 cars, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# Cars196.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars344.png: 448x640 1 car, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Cars344.png → Who owns this car?GOOGLE
#
# image 1/1 /content/images/images/images/images/Cars371.png: 320x640 1 car, 1 truck, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# Cars371.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars409.png: 576x640 1 bus, 1 train, 1 truck, 10.6ms
# Speed: 2.7ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 640)
# Cars409.png → Mene4aaaneeaERK9774ERK 977AFR E € P T
#
# image 1/1 /content/images/images/images/images/Cars106.png: 416x640 4 cars, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# Cars106.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars364.png: 416x640 8 cars, 2 trucks, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
# Cars364.png → LD2cadeeD
#
# image 1/1 /content/images/images/images/images/Cars408.png: 448x640 1 person, 5 cars, 1 motorcycle, 1 truck, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars408.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars148.png: 384x640 6 cars, 1 bus, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars148.png → MH 01 BB 550
#
# image 1/1 /content/images/images/images/images/Cars342.png: 480x640 4 persons, 9 cars, 1 truck, 1 handbag, 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Cars342.png → CENsD
#
# image 1/1 /content/images/images/images/images/Cars285.png: 448x640 1 car, 1 truck, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars285.png → MHR 26 BR 9044
#
# image 1/1 /content/images/images/images/images/Cars81.png: 480x640 3 cars, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars81.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars354.png: 448x640 3 persons, 2 bicycles, 11 cars, 2 buss, 2 traffic lights, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Cars354.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars425.png: 320x640 1 car, 1 truck, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
# Cars425.png → 6526 JHD
#
# image 1/1 /content/images/images/images/images/Cars65.png: 544x640 1 car, 6.6ms
# Speed: 2.4ms preprocess, 6.6ms inference, 2.3ms postprocess per image at shape (1, 3, 544, 640)
# Cars65.png → Q1DD@r INNTE|
#
# image 1/1 /content/images/images/images/images/Cars304.png: 384x640 1 bus, 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars304.png → JoopHychhStan howdinPiGellyIrnon
#
# image 1/1 /content/images/images/images/images/Cars238.png: 448x640 6 persons, 1 car, 10.2ms
# Speed: 3.7ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Cars238.png → MA'DoOgO?
#
# image 1/1 /content/images/images/images/images/Cars155.png: 448x640 11 persons, 1 car, 1 backpack, 5.9ms
# Speed: 1.5ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars155.png → CCB:025
#
# image 1/1 /content/images/images/images/images/Cars432.png: 416x640 5 persons, 1 car, 1 truck, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# Cars432.png → DL49 AK49
#
# image 1/1 /content/images/images/images/images/Cars337.png: 480x640 2 cars, 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Cars337.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars269.png: 480x640 2 cars, 1 truck, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars269.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars40.png: 384x640 1 car, 1 truck, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars40.png → L7IQA41232
#
# image 1/1 /content/images/images/images/images/Cars374.png: 352x640 1 car, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
# Cars374.png → S7 JDL
#
# image 1/1 /content/images/images/images/images/Cars1.png: 416x640 2 cars, 1 truck, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# Cars1.png → CoirrmPGoMN112
#
# image 1/1 /content/images/images/images/images/Cars296.png: 512x640 5 cars, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
# Cars296.png → 145
#
# image 1/1 /content/images/images/images/images/Cars373.png: 384x640 1 car, 1 truck, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Cars373.png → ROUF RAILsTN 218C, 6225
#
# image 1/1 /content/images/images/images/images/Cars261.png: 480x640 (no detections), 14.6ms
# Speed: 2.6ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Cars261.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars190.png: 480x640 1 car, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars190.png → JesuecaejurrebilorTRutHKL54 42670
#
# image 1/1 /content/images/images/images/images/Cars428.png: 384x640 1 car, 1 truck, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Cars428.png → DZIZ YXR
#
# image 1/1 /content/images/images/images/images/Cars429.png: 640x512 2 cars, 7.2ms
# Speed: 1.9ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
# Cars429.png → DOKAISER
#
# image 1/1 /content/images/images/images/images/Cars97.png: 480x640 (no detections), 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars97.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars305.png: 384x640 2 cars, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Cars305.png → sgo5i
#
# image 1/1 /content/images/images/images/images/Cars299.png: 480x640 1 car, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars299.png → fckSDN7484U
#
# image 1/1 /content/images/images/images/images/Cars228.png: 320x640 2 trucks, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# Cars228.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars277.png: 480x640 12 persons, 6 cars, 4 umbrellas, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Cars277.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars23.png: 480x640 2 cars, 1 motorcycle, 1 bus, 7.9ms
# Speed: 2.7ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Cars23.png → 227 4POLICEHanaalPUHl9214THDT
#
# image 1/1 /content/images/images/images/images/Cars329.png: 416x640 1 car, 1 truck, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# Cars329.png → LGM
#
# image 1/1 /content/images/images/images/images/Cars233.png: 256x640 1 car, 83.0ms
# Speed: 1.7ms preprocess, 83.0ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 640)
# Cars233.png → UP1C T CIJEO
#
# image 1/1 /content/images/images/images/images/Cars180.png: 480x640 (no detections), 8.6ms
# Speed: 2.6ms preprocess, 8.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Cars180.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars306.png: 640x640 2 cars, 11.5ms
# Speed: 3.8ms preprocess, 11.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Cars306.png → LAWYER
#
# image 1/1 /content/images/images/images/images/Cars137.png: 448x640 13 cars, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Cars137.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars391.png: 384x640 2 cars, 11.6ms
# Speed: 2.2ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars391.png → JBKML : 324
#
# image 1/1 /content/images/images/images/images/Cars270.png: 384x640 2 cars, 9.3ms
# Speed: 2.5ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Cars270.png → 1e0679n
#
# image 1/1 /content/images/images/images/images/Cars126.png: 480x640 (no detections), 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Cars126.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars420.png: 480x640 3 cars, 3 traffic lights, 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Cars420.png → GKip GAs]
#
# image 1/1 /content/images/images/images/images/Cars48.png: 384x640 (no detections), 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Cars48.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars114.png: 384x640 1 remote, 1 keyboard, 1 cell phone, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Cars114.png → CCGRAPHICSAP29BP585
#
# image 1/1 /content/images/images/images/images/Cars173.png: 384x640 1 car, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Cars173.png → VIRGINIAKHY-9051 7ITSLATHE
#
# image 1/1 /content/images/images/images/images/Cars107.png: 384x640 1 car, 14.7ms
# Speed: 2.9ms preprocess, 14.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Cars107.png → MH2080 20Eenetette uttnrTeHl
#
# image 1/1 /content/images/images/images/images/Cars93.png: 416x640 1 person, 5 cars, 1 bus, 1 truck, 4 traffic lights, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
# Cars93.png → Cusr
#
# image 1/1 /content/images/images/images/images/Cars312.png: 384x640 (no detections), 13.4ms
# Speed: 2.2ms preprocess, 13.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars312.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars205.png: 640x640 2 cars, 1 traffic light, 12.9ms
# Speed: 4.3ms preprocess, 12.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Cars205.png → notacop]e
#
# image 1/1 /content/images/images/images/images/Cars20.png: 416x640 2 persons, 1 car, 9.6ms
# Speed: 2.5ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# Cars20.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars177.png: 384x640 3 cars, 1 bus, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Cars177.png → GOOD
#
# image 1/1 /content/images/images/images/images/Cars214.png: 416x640 14 cars, 1 truck, 4 traffic lights, 9.9ms
# Speed: 3.2ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# Cars214.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars275.png: 352x640 2 cars, 2 trucks, 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
# Cars275.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars131.png: 384x640 1 remote, 1 keyboard, 1 cell phone, 11.4ms
# Speed: 3.4ms preprocess, 11.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Cars131.png → CCGRAPHICSAP29BP585
#
# image 1/1 /content/images/images/images/images/Cars411.png: 448x640 5 cars, 1 truck, 12.6ms
# Speed: 2.6ms preprocess, 12.6ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Cars411.png → VIPERn
#
# image 1/1 /content/images/images/images/images/Cars200.png: 416x640 4 cars, 8.3ms
# Speed: 1.7ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# Cars200.png → KA 03 AB3380
#
# image 1/1 /content/images/images/images/images/Cars413.png: 416x640 1 car, 1 truck, 7.6ms
# Speed: 1.5ms preprocess, 7.6ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
# Cars413.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars19.png: 384x640 2 cars, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Cars19.png → EEcISHRuzukI WESIERN MOIC; `AFR 2011|'MioAcan
#
# image 1/1 /content/images/images/images/images/Cars31.png: 416x640 1 car, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# Cars31.png → Nd63 LB
#
# image 1/1 /content/images/images/images/images/Cars41.png: 640x512 1 person, 3 cars, 3 traffic lights, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
# Cars41.png → 1919XNizdBG
#
# image 1/1 /content/images/images/images/images/Cars124.png: 448x640 5 persons, 12 cars, 1 truck, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars124.png → NOT_FOUND
#
# image 1/1 /content/images/images/images/images/Cars160.png: 384x640 1 car, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars160.png → ESeEedieCenennt{Q7PLATECOH
#
# image 1/1 /content/images/images/images/images/Cars219.png: 480x640 1 train, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars219.png → KA 03 MG2784
#
# image 1/1 /content/images/images/images/images/Cars431.png: 320x640 1 keyboard, 6.6ms
# Speed: 1.2ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# Cars431.png → KLINDBOSS
#
# image 1/1 /content/images/images/images/images/Cars222.png: 384x640 1 car, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Cars222.png → 26 SPF-4
#
# image 1/1 /content/images/images/images/images/Cars341.png: 448x640 1 car, 1 bus, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Cars341.png → Tsm IC %
#
# image 1/1 /content/images/images/images/images/Cars405.png: 384x640 1 car, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Cars405.png → Iincaeb =
#
# image 1/1 /content/images/images/images/images/Cars359.png: 480x640 2 persons, 6 cars, 5 buss, 1 truck, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Cars359.png → RRIEL
#
# image 1/1 /content/images/images/images/images/Cars400.png: 448x640 1 car, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Cars400.png → ToB83uS9
#
# image 1/1 /content/images/images/images/images/Cars182.png: 384x640 1 bus, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Cars182.png → VZLAF
#
# image 1/1 /content/images/images/images/images/Cars56.png: 320x640 1 keyboard, 6.7ms
# Speed: 1.2ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# Cars56.png → KLINDBOSS
